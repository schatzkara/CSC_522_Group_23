# %%
headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
        " AppleWebKit/537.36 (KHTML, like Gecko)"
        "Chrome/74.0.3729.157 Safari/537.36"}

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

reviewlist = []

def get_soup(url):
    r = requests.get(url, headers=headers, params={'url': url, 'wait': 2})
    soup = BeautifulSoup(r.text, 'html.parser')
    return soup


def get_reviews(soup):
    reviews = soup.find_all('div', {'data-hook': 'review'})
    try:
        for item in reviews:
            review = {
            'product': soup.title.text.replace('Amazon.co.uk:Customer reviews:', '').strip(),
            'title': item.find('a', {'data-hook': 'review-title'}).text.strip(),
            'rating':  float(item.find('i', {'data-hook': 'review-star-rating'}).text.replace('out of 5 stars', '').strip()),
            'body': item.find('span', {'data-hook': 'review-body'}).text.strip(),
            }
            reviewlist.append(review)
    except:
        pass

for x in range(1,20):
    link = "https://www.amazon.in/Fire-TV-Stick-Alexa-Voice-Remote-3rd-Gen/product-reviews/B08R6QR863/ref" \
           "=cm_cr_getr_d_paging_btm_next_" + str(x) + "?ie=UTF8&reviewerType=all_reviews&pageNumber=" + str(x)
    soup = get_soup(link)
    print(f'Getting page: {x}')
    get_reviews(soup)
    print(len(reviewlist))
    if not soup.find('li', {'class': 'a-disabled a-last'}):
        pass
    else:
        break

df = pd.DataFrame(reviewlist)
df.to_excel('sony-headphones.xlsx', index=False)
print('Fin.')
# Out:
# Getting page: 1
# 10
# Getting page: 2
# 10
# Getting page: 3
# 10
# Getting page: 4
# 10
# Getting page: 5
# 10
# Getting page: 6
# 10
# Getting page: 7
# 10
# Getting page: 8
# 10
# Getting page: 9
# 10
# Getting page: 10
# 10
# Getting page: 11
# 10
# Getting page: 12
# 10
# Getting page: 13
# 10
# Getting page: 14
# 10
# Getting page: 15
# 10
# Getting page: 16
# 10
# Getting page: 17
# 10
# Getting page: 18
# 10
# Getting page: 19
# 10
# Fin.

# %%
df
# Out:
#                                              product  \
# 0  Amazon.in:Customer reviews: Fire TV Stick with...
# 1  Amazon.in:Customer reviews: Fire TV Stick with...
# 2  Amazon.in:Customer reviews: Fire TV Stick with...
# 3  Amazon.in:Customer reviews: Fire TV Stick with...
# 4  Amazon.in:Customer reviews: Fire TV Stick with...
# 5  Amazon.in:Customer reviews: Fire TV Stick with...
# 6  Amazon.in:Customer reviews: Fire TV Stick with...
# 7  Amazon.in:Customer reviews: Fire TV Stick with...
# 8  Amazon.in:Customer reviews: Fire TV Stick with...
# 9  Amazon.in:Customer reviews: Fire TV Stick with...
#
#                                              title  rating  \
# 0                         Not for me, a power user     4.0
# 1  NICE.EPIC.WHAT TO SAY THEY IMPRESS ME IM IN 🤪🤪🤪     4.0
# 2           Remote doesn't connect with Hyundai tv     4.0
# 3                                           review     4.0
# 4                                      Good device     4.0
# 5                   Must buy to make your tv smart     4.0
# 6                                    Faulty remote     4.0
# 7               Supercalifragilisticexpialidocious     4.0
# 8               Able to access streaming platforms     4.0
# 9   The performance is good with in terms of price     4.0
#
#                                                 body
# 0  Pros:* There is a base line level of quality p...
# 1  BUY NOW 2700 IS NOT BIG AMOUNT BUT FOR UR INTE...
# 2  Fire stick is good, but remote is not able to ...
# 3  This fire stick are full value for money produ...
# 4  Nice product and working good. My normal TV in...
# 5                            Working everything fine
# 6            Remote not working but fire stick is ok
# 7  Product is good but 1 start deducted need beca...
# 8                                        Easy to use
# 9  Really liked the stick, the performance is goo...

# %%
# from bs4 import BeautifulSoup
# import requests

# Alexa_Reviews = []

# for i in range(1, 5):
#     link = "https://www.amazon.in/Fire-TV-Stick-Alexa-Voice-Remote-3rd-Gen/product-reviews/B08R6QR863/ref" \
#            "=cm_cr_getr_d_paging_btm_next_" + str(i) + "?ie=UTF8&reviewerType=all_reviews&pageNumber=" + str(i)
#     print(link)
#     page = requests.get(link)

#     soup = BeautifulSoup(page.content, 'html.parser')
#     review = soup.find_all('span', class_="a-size-base review-text review-text-content")
#     if review:
#         for y in range(0, len(review)):
#             Alexa_Reviews.append(review[y].get_text())
#     else:
#         break

# print(Alexa_Reviews)
# Out:
# https://www.amazon.in/Fire-TV-Stick-Alexa-Voice-Remote-3rd-Gen/product-reviews/B08R6QR863/ref=cm_cr_getr_d_paging_btm_next_1?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Fire-TV-Stick-Alexa-Voice-Remote-3rd-Gen/product-reviews/B08R6QR863/ref=cm_cr_getr_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# ['\nPros:* There is a base line level of quality present. In the short time that I used it, the hardware and software mostly worked well.* Software updates are provided for the device and apps.Cons:* Considering that its a paid product, the amount of ads / recommendations is high. Its possible to tone them down, but not to remove them.* Sleep does not work with desktop monitor. Screen always stays on.* Stick format makes it hard to remove and add to different devices.* A bit slow to use. Third party apps are generally slower and can be buggy.* The level of customization available is low. Not possible to remap remote buttons, change screen saver or enable display off after idle.\n', '\nBUY NOW 2700 IS NOT BIG AMOUNT BUT FOR UR INTEREST OF ENTERTAINMENT U NEED AND WORTH IT NON SMART TVS WITH HDMI SUPPORT THIS IS SMART TV PLUS I HAD NONSMART TV OF 32 inch tv BEETHOSOL AND THIS I WON WORLD,All apps subscription LIKE NETFLIX, YOUTUBE,SONYLIV,ETC TO WEBLINKS TO NEEDS GO TO CROME APP AND SETTINGS TO 10 SEC ALL ENTERTAINMENT IN ONE APP FORGET THINKING IM NOW.im not borthing it is voice control or connection of higher expanse i just buy it.\n', '\nFire stick is good, but remote is not able to connect with Hyundai tv... If you have old tv of non-branded then the remote will not connect with tv\n', '\nNice product and working good. My normal TV in now became smart tv. Overall a great product. Highly recommend.\n', '\nRemote not working but fire stick is ok\n', '\nProduct is good but 1 start deducted need because sometimes unable to open apps, I have to clear cache for this app to open.\n', "\nReally liked the stick, the performance is good and all but they should have included 4k support with this rather than buying a more expensive fire TV stick 4k just to get 4k.The only thing that I didn't like is the pricing, the fluctuate between 2000 to 4000 which is really frustrating coz you have to wait for the price to get below 3k to buy. Just make the permanent price 2.5 to 3k. Btw I bought it for 2.8k\n", '\nI have an Samsung Smart TV which was 4-5 yrs old and hence it did not received new updates of various OTT platforms. Also many OTT apps were not available on the samsung smart store. Fire Stick completely changed the game and viewing experience. Even the Picture quality had improved to a great extent as the TV now runs on Firestick software instead of the TV. Apps work seamlessly and its a must buy to make ur TV upgrade if its 4-5 yrs or even more old.\n', '\nReally good\n', '\nAfter one year the product stopped working had to get a new one as this product was good\n']
