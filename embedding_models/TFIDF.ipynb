# %%
from google.colab import drive
drive.mount('/content/drive')
# !cd /content/drive/MyDrive/CSC522
# !pwd
print('done')
# Out:
# Mounted at /content/drive
# /content
# done

# %%
import pandas as pd
import gensim.parsing.preprocessing as preprocessing
import sklearn.metrics
import pprint as pp
import numpy as np
import gensim
import nltk

from gensim.models import Word2Vec
from sklearn.neighbors import KNeighborsClassifier

# %%
all = pd.read_csv("/content/drive/MyDrive/CSC522/data/balanced_data_set_3000.csv").dropna()

# %%
from sklearn.model_selection import train_test_split

X = all["body"]
y = all["generalized_rating"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=200)

# %%
import gensim.parsing.preprocessing as preprocessing
import sklearn.metrics
import pprint as pp
import numpy as np
import gensim
import nltk

from gensim.models import Word2Vec
from sklearn.neighbors import KNeighborsClassifier

nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
#preprocess function
def preprocess(data):
  lines = []
  for r in data:
    try:
      # preprocess here
      lines.append(r)
    except:
      lines.append(r)
  return lines

# %%
x_train = preprocess(X_train)
x_test = preprocess(X_test)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer 

# settings that you use for count vectorizer will go here 
tfidf_vectorizer=TfidfVectorizer(use_idf=True) 

# just send in all your docs here 
train_=tfidf_vectorizer.fit_transform(x_train)

test_=tfidf_vectorizer.transform(x_test)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier

def analyze_resuts(x_train, y_train, x_test, y_test):
    # clf = KNeighborsClassifier(n_neighbors=4)
    # clf = DecisionTreeClassifier(random_state=10)
    # clf = RandomForestClassifier(random_state=10)
    clf = AdaBoostClassifier(random_state=10)

    clf.fit(x_train, y_train)

    acc1 = clf.score(x_train, y_train)
    acc2 = clf.score(x_test, y_test)

    print("Baseline accuracy: " + str(acc1))
    print("Tested accuracy: " + str(acc2))

    y_pred = clf.predict(x_test)

    labels = [-1,0,1]

    report = sklearn.metrics.classification_report(
        y_test, y_pred, digits=3, labels=labels
    )

    print("Classification report:")
    print(report)

    cm = sklearn.metrics.confusion_matrix(y_test, y_pred, labels=labels)

# %%
analyze_resuts(train_, y_train, test_, y_test)
# Out:
# Baseline accuracy: 0.6379166666666667
# Tested accuracy: 0.6183333333333333
# Classification report:
#               precision    recall  f1-score   support
#
#           -1      0.555     0.680     0.612       582
#            0      0.571     0.497     0.531       610
#            1      0.745     0.681     0.711       608
#
#     accuracy                          0.618      1800
#    macro avg      0.624     0.619     0.618      1800
# weighted avg      0.624     0.618     0.618      1800
